# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import pandas as pd
tweets=pd.read_csv('/content/drive/MyDrive/Tweets.csv')
tweets.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
tweets_df=pd.DataFrame(tweets)
tweets_df = tweets_df.drop(columns=['selected_text'])
tweets_df.shape
# Out:
# (27481, 3)

# %%
X=tweets_df['text']
y=tweets_df['sentiment']

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words=stopwords.words('english')
stemmer=PorterStemmer()

# %%
import re
cleaned_data=[]
for i in range(len(X)):
   tweet=re.sub('[^a-zA-Z]',' ',str(X.iloc[i]))
   tweet=tweet.lower().split()
   tweet=[stemmer.stem(word) for word in tweet if (word not in stop_words)]
   tweet=' '.join(tweet)
   cleaned_data.append(tweet)

# %%
cleaned_data
# Out:
# ['respond go',
#  'sooo sad miss san diego',
#  'boss bulli',
#  'interview leav alon',
#  'son put releas alreadi bought',
#  'http www dothebounci com smf shameless plug best ranger forum earth',
#  'feed babi fun smile coo',
#  'soooo high',
#  '',
#  'journey wow u becam cooler hehe possibl',
#  'much love hope reckon chanc minim p never gonna get cake stuff',
#  'realli realli like song love stori taylor swift',
#  'sharpi run danger low ink',
#  'want go music tonight lost voic',
#  'test test lg env',
#  'uh oh sunburn',
#  'ok tri plot altern speak sigh',
#  'sick past day thu hair look wierd didnt hat would look http tinyurl com mnf kw',
#  'back home gonna miss everi one',
#  'he',
#  'oh marli sorri hope find soon',
#  'play ghost onlin realli interest new updat kirin pet metamorph third job wait dragon pet',
#  'clean hous famili com later today',
#  'gotta restart comput thought win suppos put end constant rebooti',
#  'see wat mean bout foll w friiday call lose f llower friday smh',
#  'free fillin app ipod fun im addict',
#  'sorri',
#  'way malaysia internet access twit',
#  'juss came backk berkeleyi omg madd fun havent minut whassqoodd',
#  'went sleep power cut noida power back work',
#  'go home seen new twitter design quit heavenli',
#  'hope unni make audit fight dahy unni',
#  'consol got bmi test hahaha say obes well much unhappi minut',
#  'funni cute kid',
#  'ahhh slept game gonna tri best watch tomorrow though hope play armi',
#  'that end tear fear vs eric prydz dj hero http bit ly hpbg',
#  'born rais nyc live texa past year still miss ny',
#  'case wonder realli busi today come ad ton new blog updat stay tune',
#  'soooooo sleeeeepi last day school today sniffl',
#  'littl happi wine jeje ok sm free time care jaja love day',
#  'car happi big big dent boot hope theyr go write cross finger wait',
#  'im avid fan magazin love magazin',
#  'mayday',
#  'ratt rock nashvil tonit one thing suck encor like still fun show pearci hott bad boy look',
#  'love avail pm dear would love help convert vid',
#  'girl hair salon ask shall trim eyebrow old feel',
#  'egh blah boooooooooooo dunno wanna go work hangov suckkkkkk im drunk mess',
#  'visit friendster facebook',
#  'donbt like peel prawn also dont like go shop run money crawl round car look',
#  'case got new one last week thrill mine',
#  'check http twittersuck com connect tweepl hate twitter',
#  'also bore school third freelesson freistund',
#  'hm us guess',
#  'u dissappoint past day',
#  'romanc zero funni',
#  'rather earli run morn runner',
#  'bah cowork ran work late bag smack knee realli hurt',
#  'back later http plurk com p rp k',
#  'aw torn ace heart hunchback',
#  'fun speak',
#  'lost friend alon sleepi wanna go home',
#  'haha ye',
#  'give easili',
#  'better way spoil mum let kick back relax nice meal bottl favorit wine wine red',
#  'mannnn got iphon im jealou http bit ly ngnar',
#  'photoshoot',
#  'awesom work good friend',
#  'yay play show tonight boo gonna soggi work right play',
#  'chilliin',
#  'know agent let know',
#  'still smell smoke kitchenfir',
#  'celtic laker rematch sound better think lol',
#  'anyon extra kean ticket promis buy drink take rad pic fb blog flickr etc',
#  'ride one catch one summer til pop open one',
#  'good gor juz yea kno ask yesterday tha hospit talk u said',
#  'ok pop say hi check thing probabl head guttah later tonight',
#  'wow realli missin fam ili today baddd',
#  'sourc say',
#  'sooo tire',
#  'hey chang twitter account even tell',
#  'thank yyyyyyyyyoooooooooouuuuu',
#  'lucki kid wanna see loservil piti im oz',
#  'fell asleep wait ride',
#  'sick flu like thing',
#  'still repli simfing problem irap parodi video get respons sorri guy',
#  'happi star war day everyon enjoy holiday uk',
#  'mile essex give plenti warn arriv time get least one free beer',
#  'snore annoy n keep sleep like right lol honestli wud miss eva left love',
#  'miss bbi wish go tomorrow make good',
#  'well im work quit readi post publicli still beta test cool new script code',
#  'sweeeeet san fran awesom love',
#  'mounc ye last way past bedtim',
#  'hi join twitter',
#  'wait sleep pill kick gonna tire work tomorrow',
#  'eat ice cream get readi graduat',
#  'happi mother day mum',
#  'casey gone piddl littl carpet prolli freak caus new get back',
#  'hemp cloth marvel unfortun',
#  'gonna read stori bout adam lambert onlin bed nighti night',
#  'saw none baddi best',
#  'im beach pretti',
#  'certainli cheer huh',
#  'week post horribl traumat jump cholla accid cholla next dirti trick piec start emerg hand ouch',
#  'reali want go caus nice everybodi busi',
#  'awesom ocean beach know way yourbiggestfan al big fan rs',
#  'least get watch time let go pen',
#  'cool wear black time go',
#  'haha know work blip apart obviou thank reblip song nice day',
#  'safe trip joshi poo knock dead speech',
#  'woof wish allow go',
#  'u friendster add email adress add loco crime st com add leav comment',
#  'ticket',
#  'thank afrin nasal spray also got giant teacup tonight',
#  'acsm unfathom think one one kept comfort bedroom ye',
#  'aww love daddi work day week almost day still tri go sf us',
#  'mani test todayyy feel confid anyy',
#  'graduat done im littl sad anyon want hang',
#  'hahaa awesome',
#  'holi smoke star trek freak awesomeeee',
#  'hate fallout keep make jump also low health money ammo food worri get',
#  'itun lost song',
#  'gloomi weather sun must tire come play head victoria garden impuls buy haha',
#  'look forward next week math geographi english french exam total hour',
#  'poor get outsid sleep garden sun good forget suncream',
#  'well',
#  'prob hun',
#  'dad watch mtv go sim minute',
#  'absolut',
#  'matter chickade',
#  'hey mia total ador music cd',
#  'shop clean bmfing webcam chat nephew noth spesh good bank holiday monday nonetheless',
#  'need ask someth lmao love',
#  'splinter look pain heroic save mr pickl',
#  'sad',
#  'nice see tweet sunday th may celebr mother day today nice yer mom',
#  'decid tran frm relax natur hair wish whole head look like root age instant gratif',
#  'namaskar namast r marathi peopl say namaskar marathi word naaaah',
#  'congrat cuss like matter minut know reward',
#  'humou dorito oh ye',
#  'miss awesom weather movi',
#  'today go normal day hope group pilot larg airlin come last night much drink',
#  'kid terribl good evan call childlin',
#  'unfortunatley aerlingu longer fli copenhagen fli ryanair billund drive copenhagen one day',
#  'sad actual googl term suck tho',
#  'hate fight',
#  'watch didnt want win put good fight lol',
#  'car warm sprite tast like sore throat',
#  'came th cross countri beat dumbo',
#  'candl wax enjoy',
#  'unassum unpretenti suppos endear relat',
#  'tomorrow valeria lunch go get hair done im arrav late got cousin babtizm whatev spell',
#  'goooooddd morn tweet week three workout mention got new glass yesterday',
#  'hate comput much',
#  'fine go big walk today mile',
#  'want red cruiser like one lmfao',
#  'mmmmmmmm morn',
#  'neither',
#  'hour work sunday boo find time two hour lunchbreak though yeah',
#  'bugger forgot still wash machin',
#  'lauri send love bless heal thought famili peac',
#  'back hurt realli bad',
#  'ah ye know feel',
#  'night cooker dad',
#  'modem offlin week god bless g network tim left may schedul brutal',
#  'nope coquitlam',
#  'parent teacher thing yesterday bore go skl saturday lol',
#  'lichfield tweetup sound like fun hope see everyon els',
#  'big boom thunder storm almost mayb go home earli ah probabl',
#  'bevvi day twn great day',
#  'first night myer w lydia actual excit summer',
#  'good morn',
#  'best show ever',
#  'url previou post timer job http bit ly fdb remov space mess url es',
#  'think iv hurt tooth eilish cassi draw competiton draw cooki pineappl haha l',
#  'want know audit mander text repli pleas',
#  'even nooooo secret namerebecca pleas',
#  'miss neic wait see bad n grown lol',
#  'need get comput fix',
#  'realli hope car ill termin',
#  'cool peopl want find follow today english guess english tweet',
#  'sir woulda put honey',
#  'watch x men origin wolverin total love haha',
#  'vote u person myspac keep talk fake u help thru hrdest time life x',
#  'sad miss guy last night',
#  'final got call marriag counsel day late',
#  'ok',
#  'babi',
#  'today last day high school end go home sick stupid dead rat',
#  'impromptu pool parti except know swim get',
#  'lost tooth day whilst eat gum oww',
#  'happi year',
#  'oh hella forgot say offici good morn like hear go goooooooooooood morrrrrrrrn twittervil lol',
#  'phew make note case anyon els run issu',
#  'vote everi day',
#  'starv diet kill eat pm',
#  'talk',
#  'im soo bore im deffo miss music channel',
#  'nite nite bday girl fun concert',
#  'nicotin replac patch hour far good sleep hour get bit twitchi',
#  'sanderson twatter late either get repli turn',
#  'sleep lost voic coupl day ago',
#  'http twitpic com xlm hate park car get hit',
#  'heard fall wait',
#  'nightmar huggl',
#  'creeper feel disappoint cyberstalk skill internet privaci',
#  'go bed late headach',
#  'happi mother day mom',
#  'grab coffe make mom breakfast',
#  'im think im go fun tonight mayb chang come',
#  'thank major chop',
#  'haha know cant handl fame thank',
#  'got updat ipod',
#  'ye sober hahaha tanghal tapat dude haha wild knowwww plan plan go us',
#  'never miss icarli son huge crush miranda',
#  'saw jame carvil store today head realli bald',
#  'yellow http blip fm z g',
#  'mean go come back vancouv way hahah',
#  'feel smooth like chrome',
#  'ew traffic',
#  'download song tri sneak lil homework main prioriti song lol',
#  'ra ra alon need coffe',
#  'sound like',
#  'bad day day realiz mess put one happiest day life',
#  'walk class hate bike especi mine',
#  'nesmith',
#  'fail inspect know pass wo oven wo anti tip bracket sold w oven wors tax',
#  'jona brother live parti rock hard love song',
#  'happi mother day mother world',
#  'min hr min googl wave demo look lot fun would love test though http bit ly wnmsc',
#  'sleepi tabz head bed fun night listen next episod joss',
#  'except short dude larenz fineass tate yum',
#  'screw review thought wolverin awesom enough domin monaghan like',
#  'follow us recent pleas dont offend follow back hit limit hope free soon',
#  'ye work',
#  'hmmm mayb meant elud someth brand new know media',
#  'done spa meet vic late lunch',
#  'happi monday go tavar today hope everyon bless day',
#  'alway want go oz',
#  'thx',
#  'http twitpic com jaz cool luv',
#  'need repres blackberri',
#  'okay dedic th tweet fact go appl store huge crack glass screen',
#  'could ever actual allow stay',
#  'let know turn',
#  'sass detect long back sass haha',
#  'yeah think ahaha',
#  'sport bar shatranjanpoli rest ph sport bar andheri w dont know whether help googl ki jai ho',
#  'sleep accept appolog',
#  'wolverin boss serious',
#  'live pain bring',
#  'okay back later',
#  'powerblog powerblog challeng keep talk newbi follow',
#  'almost die laptop screen set bright reinstal window vista got headach insanedefault',
#  'wait tish get got drive mom crv pick ducki first time',
#  'tri decid movi friend go well lol p bibl studi nite mean day cake buy',
#  'go shower want smell school tomorrow',
#  'sigh know',
#  'discov caus bug new netplay build publish bug fix hope new beta tomorrow',
#  'free twitter tool get follow http short q http jijr com hulz http short r http org xpg',
#  'got home work chug big bottl appl juic',
#  'ye pleas dont go die cri normal lead small anim get harm',
#  'write report card soooo tire amaz day check fb soon',
#  'big brother done',
#  'good news final finish easact workout paus hour bad news resist band torn',
#  'well good morn wonder day neighborhood thank follow anoth morn',
#  'ftsk merci merced amaz tonight alway',
#  'hope ok',
#  'school done alreadi hurt much see everi day',
#  'wait listen wind blow tumblewe none old enough know someon say crackerack',
#  'hell yeah',
#  'shirt dinner need ask actual vill',
#  'know',
#  'huh smelli noooo love alex vixon',
#  'went parti last night dindin show match outfit great mind think alik anyway happi birthday ate lara',
#  'happi b day woke side earth wish bit late',
#  'thank teach valu better person day love much best mum world',
#  'happi mother day',
#  'laugh glad self confid wonder trait applaud extra loud okay',
#  'thank',
#  'twitter day',
#  'get readi week nice today stuck insid work',
#  'tre depress',
#  'felt like behav like son ate compens pig home roast sugar almond pain tum threw still feel sick',
#  'happi mother day peopl love mom lot still',
#  'sorri hear',
#  'awesom dude yay surpris celebr got meet year ago soooo friendli',
#  'make happi hear girl talk tweet nba could give nugget love',
#  'get hang twitter',
#  'know neck jack forc pay park bc turn head parallel park free space',
#  'want back http bit ly pp wz',
#  'go miss roomi longer roomi start tomorrow',
#  'bath two littl angel keyla janic',
#  'yep finish chock full spell grammat error clean tomorrow pop hehe',
#  'hahahha lol true alway rememb bd never rememb date even day',
#  'famili hang',
#  'watch ellen love dish tan gorgeou',
#  'goin hun worri',
#  'im bannish work till',
#  'morn get see let know right go go see wolverin',
#  'red top tabloid build em knock em',
#  'tonight parti w girl minu vita',
#  'made sad thought jump joy',
#  'simpl',
#  'pic upload babi pic cat missi adult pretti littl kitti batti kitten heaven',
#  'saw play amaz',
#  'glad break twitter virgin two',
#  'dinner fam miss',
#  'live want better bound bad egg though soon learn',
#  'hell yeah kellynn got twitter final',
#  'know worth shot though',
#  'open facebook account littl confus realli get twitter seem much better',
#  'ship stuck',
#  'dustbin babi cannot wait x',
#  'go dwell happen pass shame support life x',
#  'nan',
#  'look like offic tv get mlb network look like mlbn televis det bal game today wieter',
#  'home empti hand comic found today shall indulg cupcak magnolia bakeri',
#  'lay bed til workkk oh life definit pinch nerv',
#  'today busi day exhaust',
#  'go go sunday got much go weekend',
#  'sorri hear ur flight got cancel blow',
#  'ohh tooth hurt ohh im sad hurt',
#  'get distract like thank new follow take troubl follow other feelin love',
#  'u think u bill ha ii finish pay mine broke',
#  'sure say big jst saw pic u ur last bday look pretti miss',
#  'sore throat plan tet outing marwel though good time',
#  'mcfli gig last nightt omg amazin didnt sit whole thing mcfli see best mate tutu',
#  'day without sleep migrain thought life postr meant relax',
#  '',
#  'suck',
#  'when sway sway winner announc',
#  'k check',
#  'pretti well wide awak',
#  'want wake earli get coffe tomorrow today go busyy day keep write booo whoo',
#  'miss daddi mommi',
#  'dog offici depress brother dog gone want go outsid play half heartedli',
#  'realiz forward text msg iphon',
#  'frist post find new car parent excit',
#  'argh noo miss killer wossi suck miss brandon total failur anyon know repeat must investig',
#  'serious bore without anyon talk tire enough sleep',
#  'lost pleas help find good home',
#  'peter gordon morn go piec wanna hide go piec almost die ever http blip fm yk',
#  'ok got bit bad back lift drum hardwar car downer',
#  'lmao smh one threw',
#  'oh nice go',
#  'get readi work work weekend',
#  'gonna celebr mother day famili gonna start parti tonit',
#  'agre',
#  'comput hopeless everyth els',
#  'degre gross sky thunderstorm perfect match mood lol',
#  'nd aww thank',
#  'sorri rb ps',
#  'saw amaz heeel big',
#  'stuck finger throat bunch bump tongu throat',
#  'dang last url went http blip fm aigm',
#  'ohoh miss ur tweet im gonna stay awak night see announc time differ',
#  'damnit suck one one thought drag back lol',
#  'boss move nyc',
#  'sooo crazi fever',
#  'spend saturday morn take note research essay stupid recal book use fair',
#  'think need new friend',
#  'look forward gig ireland see ya',
#  'pleas review sunehr ad placement http tinyurl com oow mk',
#  'aww loooov',
#  'hungri twitter want food',
#  'awesom lucki',
#  'yea know tell everyth ps send direct messag tell haha',
#  'haha im jewish love one',
#  'great time beer garden wit boyo think sun got bit though feel bit ill',
#  'l day matt fun weekend',
#  'u realli think mayb ur right lol btw phone u use think u told b might app u',
#  'feel pain mine way',
#  'come home two day',
#  'sadli come one',
#  'cant wait see boy tomorrow',
#  'ehhh check dentist app next week though get molar pull root canal',
#  'aww miss drive elmwood',
#  'omg wango tango awsom love babi take',
#  'version live interact tran siberian ticket planner launch http tinyurl com c ljwm cool',
#  'realli wish could go',
#  'yeah real hard know get smile',
#  'decemb good next big birthday fli sure',
#  'made night way funni',
#  'woo cav happi mother day',
#  'make face get home mom watch soap',
#  'go work',
#  'believ went got boba without',
#  'today',
#  'thank warm welcom make plan arriv time air',
#  'day count',
#  'sorri friend swamp deadlin right famili visit boot charad',
#  'brainfreez',
#  'discov shortcom graviti use twitpic integr subtract pic url charact limit',
#  'sunburn peel',
#  'perki purpl nail polish perki chip',
#  'http twitpic com sx put camera smoker pit longer vandal door without caught',
#  'lay alon sinc mook soo comfi f n play pen thought ill first one cuddl',
#  'hate dentist',
#  'noth aim join sorri',
#  'take twitter break cell die',
#  'qood morninq',
#  'write english origin write storyyyyi listen littl respect erasur aaaaaah',
#  'need follow',
#  'wish could get nail done stupid job',
#  'littl wormi labyrinth sadli pass away today ok he still around happi ghost form aww http twitpic com aim',
#  'pant idea could new attempt world wide attract busi back airlin',
#  'good one',
#  'yep infact popular miss india talent film actress lot',
#  'dosen want go work tomorrow',
#  'daniel dsd voic great',
#  'wish birthday massacr would come australia think said think tho http tinyurl com p lfch',
#  'hope go red lobster weekend',
#  'x atl u mean jack barakat wow u ever gone hous hehe mean ur ssoo lucki address',
#  'sure hope becom afternoon',
#  'mean famou congrat',
#  'phone pass away yesterday jump tabl search new phone',
#  'fantast friend includ sever one met thank life amaz peopl',
#  'tamlyn wish cool sock draw',
#  'rice crusti bread chili aawww',
#  'like mind even dear',
#  'come save pack pleas',
#  'ye love tea make typic english',
#  'mouth sure',
#  'dec de final hour histori pm went highschool make homework friend',
#  'pancak lemon sugar thank',
#  'si bueno guess entertain',
#  'hunrgi right heel kill hardli walk',
#  'electron key stop work keyhol cant get car much technolog',
#  'yay three follow good know one person big wide world like fishi',
#  'name toni hey poor toni',
#  'goodmorn',
#  'took shift tomorrow realli feel like work right',
#  'love mine happi mother day mom john taylor much love',
#  'saw black snake garden went back pictur gone',
#  'http twitpic com wukt bought ludi rug dog best',
#  'waterfront anymor faccia luna clarendon',
#  'love mum much happi mother day wonder mother',
#  'slip caught flu feel like poop',
#  'urg play wow wait week til im dad day til mcfli im excit l',
#  'ok passeng one aliv dead know til end cri',
#  'discov share g reader even know sigh g reader newb',
#  'chill tonit cannot spew venom write funni seem like style',
#  'u pleas pray lord know need',
#  'aaaaaw want live usa',
#  'morn tweepl',
#  'hey get',
#  'hour sleep rest need',
#  'make day much better rough one mention love new photo',
#  'want sit home prom night someon hang',
#  'head home foot surgeri wish boyfriend come cuddl',
#  'concert tonight chackin come tomorrow',
#  'happen thought come back today',
#  'lol dammit well next time',
#  'lol ever forget',
#  'still jealou',
#  'http twitpic com qv forev ethan',
#  'im sad im give first didnt noth',
#  'week mine easi final',
#  'wow beauti pictur way straight want let know bella',
#  'arch draw check mvcc cad degre look good',
#  'peopl pencil sharp sharpen pencil philosophi',
#  'go home usual mr posit one daze well min tomorrow',
#  'alway lee let go pari',
#  'know want come keep compani whilst mum friend night nice even',
#  'cook dad lot fun kitchen togeth',
#  'bounc rush make feel nauseou',
#  'woolseri morn hope see north molton u clinch north devon leagu titl love day',
#  'play singstar without fave duetter',
#  'miss bb cereal nut think like everi kind avail',
#  'weird oh draw',
#  'woke mum sing new gn r cd replac bought im good daughter',
#  'bird oh man cool sleep yet night',
#  'mile go that ok u radio alwa help',
#  'street fighter iv skill lack beat seth easi',
#  'fil cool peopl like',
#  'good morn work espn sunday night basebal hope get rain',
#  'think honeymoon good life either honey moon joseph arthur',
#  'son got stung bug first time littl finger slightli swollen',
#  'hour ago came realis went buy someth onlin',
#  'oh refer lil exchang lj regard twitter archiv post',
#  'bump dj opu drunk car lmao act like u know',
#  'kiss feet peopl kick anyth want morn everyon hope best day ever',
#  'brief preview http bit ly ehcfp omg jame creepi role scare',
#  'miss crab leg attend go away instead',
#  'hick mean',
#  'gettn readi take trip jersey dad good need new heart whoeva see pleas say prayer dad',
#  'back soon need run shop cut grass',
#  'plan transform bedroom today random',
#  'home tomorrow run spin time chiropractor laundri shop visit famili miss nathan',
#  'that anoth sponsor',
#  'us go stuck offic without window',
#  'sad make proud',
#  'sorri tri keep',
#  'home alon hw',
#  'accord quarter famili six live poverti',
#  'plan spend money go well',
#  'upload bamboozl pictur facebook',
#  'congratul guy finish month earli booo',
#  'actual wish back taho miss',
#  'woke wanna stay bed',
#  'bday june wack ihav seen promot bday parti someon better finagl asap',
#  'would great vip act enjoy see noooo',
#  'mari wish could make hate commut sometim',
#  'workin long day today hope make good tip',
#  'went quick chanc lol',
#  'hate headach mayb readi rock',
#  'thank support',
#  'realli android twitter app tweeti calibr',
#  'good day drive mountain visit kati eat chip fudg stock love smell soap',
#  'nyappi mother day mom',
#  'yeah im gonna take ur pictur ipod babi',
#  'traumat moment childhood dog massacr babi bunni brother got bb gun',
#  'lol wish way micros everyth lol',
#  'organ itil forget peopl fail preach convert peopl http tr im kwua',
#  'libertin um glad enjoy',
#  'dinner even play card alreadi pack readi head home tomorrow go home',
#  'im allerg cat tonsil get swollen hurt dooo',
#  'say feel mama tuck night lone get tomorrow tough',
#  'miss alot one day',
#  'sound like great night glad success',
#  'thank share',
#  'say mlia instead fml hope find soon',
#  'garden go well almost corn pea onion beet yet though',
#  'nah jkin hot bore',
#  'ahhh sqeaki clean fresh even though wear dirti cloth love two half men amaz',
#  'ye read mani time',
#  'cuz play grown twitter',
#  'live ignor',
#  'nope tell want cameo cream',
#  'awwww gonna miss',
#  'quit like worth relax place nice coffe shop fresh air mani oik',
#  'terribl haha new fact cost part kind spock',
#  'today love day fun even',
#  'beto pizzeria banksvil rd believ beachview area sorri answer like year later',
#  'sigh sister bein strang came way copenhagen london phone turn wanna see dammit',
#  'amaz',
#  'barb tri figur dsl aint connect need googl go home comput start work soon smh',
#  'sick sad miss martini loung tonight',
#  'seem realli quiet tonight jealou clearli excit life bed think',
#  'realli wish spare cash buy new punch wii',
#  'aw go toronto anymor',
#  'sorri hear mom realli suck',
#  'feel hope smooth flight safe mucho amor boston',
#  'sleep watch hgtv afraid infomerci take',
#  'get famili readi kayle graduat gonna make sad',
#  'sweet dream',
#  'hay wat ur aim chat',
#  'okay kool might tour summer long make happen',
#  'pain big toe got stomp hokey cokeu throb anyon suggest heal',
#  'time watch op dead like sleep',
#  'dinner grandma sinc mum',
#  'haha thank histori invent televis influenc america lol',
#  'yea wassup',
#  'stupid job idk',
#  'shop til drop come bac sunshin miss u',
#  'like pic lucki girl',
#  'thank anxieti issu year think make first coupl day fine',
#  'around hour left day weekend waaaay much work',
#  'feel love mom got nikon cool pix birthday',
#  'attempt somehow extend inner class would close closur find ref atm',
#  'ye join us requir cupcak donat',
#  'hard time talk new peopl pretti sure make good impress',
#  'rc haha yup still terribl headach super swollen puffi eye dont think im go today ugh',
#  'access site',
#  'sun shin last',
#  'slowest train ever stop everywher miss quick train minut',
#  'nup cd either whole bunch zero one free',
#  'graduat day feel like failur',
#  'op lol wasnt suppos got twitter',
#  'think ever tierd life ugh goodnight sleep tomorrow',
#  'u go today girl',
#  'doesnt want anymor',
#  'bad hair day',
#  'headach',
#  'sorri guy sign sorri everi',
#  'okay okay like rest sane popul world hate monday',
#  'mozart requiem',
#  'think bit love creation wit physic attract although great style',
#  'michael hey thank anoth great day go sleep chat tomorrow sweet dream',
#  'bet cool sr huh stop sweat sinc noon dad pack',
#  'ohshnapsss piss blair usual hahah yeeeah bake cooki',
#  'bueno hollykin need feel better asap p miss done uni soon soproudofy',
#  'http twitpic com v vr cool mother awesom hair style wish happi mother day',
#  'happi mother day mother',
#  'express watch http tinyurl com eqbw',
#  'stupid bipolar weather ruin day',
#  'want tell think bodi odour',
#  'nice beta easport still news onlin madden',
#  'that pretti bad qualiti probabl worst pic u post till date',
#  'miss call',
#  'unfortun us look like funni peopl twitter move fb start flitter',
#  'came back karaok eat dinner emili sooooo much fun',
#  'discrimin bad thing learn say children would say master year ago',
#  'sure talk fabul part though sorri dear',
#  'see sec clip new moon trailer etonlin com check big teas though',
#  'got back work feel pretti good work',
#  'ahhh satz blend save',
#  'matter bet would great love right go',
#  'dh finish make giant trio candi bar thank heaven work mate treat tomorrow',
#  'ear pop',
#  'work diffus irrit traffic sure help mother f alway real bad day th help plan stuff',
#  'submit resum day saw answer back oh well',
#  'catch week lost grey hous quiet',
#  'love ryan housewif make smile',
#  'sooo kinda sick n tire bs guy dish',
#  'boo hope fake alien stori tinfoil cover beachbal photo',
#  'hey phillll wazzuppppp',
#  'miss westcott micro apollo',
#  'great buy lunch get pay cut next month',
#  'final gone beach yeaaaah',
#  'ranjan ever mention nice awesom dude',
#  'last weekday noth school start next week',
#  'hello gorgeou girl nice new pic today',
#  'ok duet hyster lol',
#  'ok turn twitter devic updat get new batteri phone goe fulli charg dead hour',
#  'michel hot mama chichi grand',
#  'either way alway tend make followfriday list sweeti rock much',
#  'one know like boil peanut',
#  'watch th episod numb rs love throwback first episod use sprinkler theori',
#  'sleepi feel weather ugh tonsil need compani somebodi talk',
#  'pleas get cell phone better camera pictur real bad qualiti compar miley took',
#  'ichigo tri carri aswel bless suppos mayb kid',
#  'booziest weekend long time good fun though',
#  'count hour lost sunshin weekend',
#  'plan tri call doctor though go well mostli plan',
#  'hoooray hook alreadi',
#  'ok good day',
#  'agre everybodi would excit goe ohhhh nooooo ms screw',
#  'edg left contributor list month issu x ff werd',
#  'ooo growl yummi time come soon huh oh yeah hunt combo tshirt think find one',
#  'im back z index problem',
#  'anyon bore work',
#  'hate life moment mani no delic littl mind take',
#  'www myspac com fashionisthenextc check start new tee limit edit differ way check facebook group',
#  'husband girl',
#  'think vega good idea place see',
#  'first day summer suck overcast cold summer',
#  'hi one kiwi artist anoth kiwi artist',
#  'say happi mother day mom http plurk com p stkr',
#  'oooo ok havent accept friend request',
#  'sorri tweet bgt poor wonder crazi weird greg fair silli littl girl never go cope urgh fair',
#  '',
#  'michel thank follow love good caus',
#  'avail area would',
#  'friday hour free tomorrow oh well',
#  'meet time tri win someth prize friday',
#  'wait cramp',
#  'philosophi final today thank day',
#  'plan go follow ok',
#  'let guess skip sport bought new pinkish outfit',
#  'rain pleas come',
#  'pleasur',
#  'st present senior board fml',
#  'lol know funni ahaha',
#  'wide awak grouchi',
#  'thought thing get wors get even wors tonight bet life miseri',
#  'app',
#  'lol hi emmi latin would help studi aptitud test get grad school that wanna take',
#  'supper tonight kurumi minut',
#  'kap think cute everi night okay',
#  'happi skool let today last day yippe r p jackson tyler morri alway love never forgotten',
#  'hi mariah',
#  'home cat right',
#  'where music mannnn inbox still empti',
#  'atm http twitpic com jmeh oh yeah appl juic rebel',
#  'sorri still sick u know know u guess pelzer present',
#  'nice one',
#  'exam today go get licens renew birthday get closer',
#  'gotta get creativ mother day gift gonna win love',
#  'think gonna rain',
#  'aah well friend wonder great weather good',
#  'yrbook sign w evryon fun gna miss evryth',
#  'lost artist abil',
#  'close enough could run get one',
#  'stone cold crazi',
#  'total austin power withdrawl sympton darriu withdrawl symptom mommi minn withdrawl syamptom',
#  'xo pretti took like hour ursssss',
#  'senior last day',
#  'crisi forgot fring comb men one help',
#  'alreadi got ticket thank make sure though',
#  'thank new follow',
#  'get closer rather real lobbi date chicago blogher squee',
#  'lost voci adel laugh lol still wonder colleg week',
#  'kill boy oh sorri get repli noth ye know nirvana',
#  'busi work new kit coupl interview done yea weekend pray uncl still young massiv stroke',
#  'get bitten rabi infest person last night yay gonna scare rachel quarantin tonight shall fun',
#  'nooo roo cri omg want slap sing fine nowher boohooooooooooo',
#  'watch simpson',
#  'good morn court crossfit bibl studi someon special hous http tinyurl com cj',
#  'great time london',
#  'work soon way soon',
#  'phaket annelies want',
#  'emerg room cousin got mad flu walk breath hospit alway cold',
#  'thank greet',
#  'hungri wife bodyshop parti bring takeaway home much longer parti go',
#  'http twitpic com wb pretti babi',
#  'invit hous instead',
#  'bit ben thai ed',
#  'stackeoverflow http bit ly nfk',
#  'jungl book sooooo cute noth eat drink',
#  'dead stop express lane would happen choos take way ugh hope get move',
#  'okeef yay twitter secret celeb crush much info',
#  'ah ok thank youuuuuu',
#  'twitter fail life sometim oh well http tinyurl com qkxh q',
#  'phone call yet minut pluck courag wish phone would ring',
#  'point gear question post cant get rest dreadweav set',
#  'remind much omaha girl use date guess jean calvin klein wore',
#  'sherrieshepherd gave link http www brentozar com twitter give twitter tip hope help',
#  'love mini',
#  'yeah okay ice ace bandag sit twitter lol thank',
#  'gorgeou',
#  'guess relax dinner movi tonight look forward day work',
#  'laptop grew speaker watch charli sound',
#  'rofl uh huh',
#  'funni',
#  'well look fab even say',
#  'deadlin',
#  'terribl headach need relief',
#  'two month ago becam irrelev',
#  'final sunni day sick go outsid play',
#  'good luck excit',
#  'work vacat thailand get excit everi day',
#  'home till like next month',
#  'final chanc show genuin love depend selfish love hope heart goe sorri ur pain',
#  'game bad leav hi',
#  'screw sat us',
#  'got im anoth co worker got laid lot peopl becom unemploy',
#  'exact one think bestttt',
#  'easti go anytim',
#  'googledoc folder instead label like gmail kind like label',
#  'lemm guess ran mile gym wake kid go beach record studio',
#  'never knew dentent hard get',
#  'pacquiao fight fun home wif fam melissa sat today mission ikea srsli differ freeway ge burbank',
#  'nail broke haaaaaaaaat',
#  'dang disappoint',
#  'yep',
#  'much longer nkotb block parti love need go bed wonder time lol thank',
#  'thank mom seed larger alreadi crack plant hope avalina dud',
#  'anyon want buy anthropomorph planter http tinyurl com sru avail till st',
#  'beauti day outsid today shame stuck offic blind shut stop glare',
#  'woke sun start rain',
#  'creativ vado stock walmart com miss thank tweet',
#  'hate weather',
#  'cultur tour loiusa famili kangaroo sight see cemetari love',
#  'flap taco nice pleb came',
#  'oh yippe lyn z way get celebr mother day first time mother',
#  'chillaxin busi bankholiday hope everbodi gd wkend holiday day',
#  'havin much better day today finish last twilight book yesterday class start next week get yall',
#  'new motorcycl pop cabl alreadi wow ride hard',
#  'check flyer design notari retrograd http rachellovespeac blogspot com let know think',
#  'thank welcom back',
#  'want experi snow snow suck',
#  'sore head',
#  'offic tri solv mysteri whose blood bathroom toilet eewwwww',
#  'awwww love car soooo cute tonight love carl yr old sad lol',
#  'bryan repli wingnut',
#  'watch southpark anoth minut',
#  'thank ami video awesom see tmh amaz bounci bounci bounci',
#  'lmao ha simpli want go ny',
#  'bore cant go habbo stupid ban',
#  'tri shoe new look',
#  'earli wanna go back sleeep',
#  'think sister refusn get ticket next week',
#  'oh wow hope ok u take vet',
#  'die wait magic jack read',
#  'woken',
#  'hahaha oh man pleas come pomona would love see everyday instead like year',
#  'jon made one greatest dinner ever roast pork tenderloin bed wild rice bed mix green yummi sauc wine',
#  'nooooo rain leav beach',
#  'shower class class take care ladi friend write like tomorrow',
#  'rockstar photograph shoot went great tonight littl differ usual stuff nice',
#  'great pic tri start sell race photo runner',
#  'goodmorn twitter oh gosh woke soooo nice lol oh hai thar twittervers happi mothersday everybodi especi mine',
#  'dulay swear took hour get bel air alabang ye love reminisc hk trip',
#  'hubbi went pick fring comic today store work store busi comix houston web',
#  'world amaz',
#  'idea im complet lost',
#  'gadgetopia need dm follow send email',
#  'awww he cute wish could gone',
#  'got cabl set win got lock put door win feel tad neglect fail',
#  'think may look littl silli also camera broken photo',
#  'great talk grace awesom god work somehow start remot control work',
#  'day beast',
#  'listen',
#  'oh u hit famili emerg lil delay wait see',
#  'sit home noth gonna like weekend',
#  'oh nevermind think thing unsalvag',
#  'flew brisban lax today great flight love light shame one drink limit though',
#  'think go sleep consid hav b hr',
#  'told often wash hair would never speak',
#  'spent hour look blog topic end invent grrrr http bit ly qrz',
#  'seem disappear life',
#  'happi mother day mom everi mom everywher stroll beach later hope',
#  'ohhh wanna go gahhh dunnooooooo confuzzzledd',
#  'kittykat hello new follow haha ya',
#  'haha best thing offic birthday hey',
#  'never knew could miss phone much hour till told back till',
#  'lay aww well randomli woke sleep mani thing mind',
#  'done alreadi one proof noth fair world http bit ly uemq',
#  'go see long',
#  'better come time count els bam',
#  'prd take long time review',
#  'u know kid say well realli',
#  'ugh wanna play dnd know go fail final need studi',
#  'hi thx follow teach chines lesson youtub pl feel free look www youtub com chineselearn',
#  'sad say fat tear',
#  'thank might take offer',
#  'tri find driver microsoft lifecam vx webcam find anywher anyon link',
#  'final get lay bit major headach',
#  'ye go see star trek sooooo much fun',
#  'mitchel idea much want call cost load call england',
#  'stupid accident gave honey atom flavor buffalo wing stomach feel aw im sorri babi',
#  'relax thank hope get put feet tomorrow enjoy day',
#  'yessir right',
#  'night',
#  'write music lit final paper mozart ein klein nashtmusik mom give hand actual great time',
#  'got crush issu tomorrow friend go india whole summer im back sad',
#  'warm',
#  'ada acara menarik lain key vip di channel v ttg straight yg dikasih task approach stranger crowd hmm',
#  'well hit see depend',
#  'aww thanx andi',
#  'goodi bag car boot includ cute cross stitch bird craft room man sell sweeti',
#  'finish iron cloth church gonna walk dog grab shower shave jottonia look good',
#  'shower time',
#  'coooooooool dooooooooown patienc virtu',
#  'gotta drop car part buddi press dentist http yfrog com v j',
#  'cant call im work',
#  'go courthous pay tag tax car gonna expens',
#  'tire readi bed realli mood salt pepper chicken wing noodl money chines',
#  'usual two famili parti today happi birthday lili http twitpic com w',
#  'final yay serious made day oh fellow hell ruler',
#  'goodnight magic pretti world',
#  'doesnt hangov get readi good ol english fri',
#  'wait put stori stereo skylin know put boooo',
#  'work',
#  'starbuck farrah',
#  'ginniejean lot mojo place ye',
#  'third date went well move fourth',
#  'mad tire hol miss chomp chomp terribl',
#  'final start assign',
#  'good morn readi start week',
#  'read good thing bout feelin tonight proli finish tomorrow star trek',
#  'glad final done final',
#  'watch thing comcast miss boo like crrrrrazi',
#  'rain almost perfect day cloth wet',
#  'yeah went day im tri get back novemb mom super soak star weekend',
#  'miss u guy prob b bk til august sumtim come bk anytim b ill sure let u kno',
#  'okay make sure alright kk cuidalo let know got friend us aha',
#  'round way ahv copi public contact person contact first big deal',
#  'tri figur',
#  'bob updat leav vet test xray',
#  'went see hannah montana movi saturday love still cant work twitter though',
#  'lol done one b victim lol',
#  'would slip fall dirti school bathroom floor fml',
#  'got confirm pizza time ex co worker friday look forward',
#  'well paisley one cone thing around head funni feel bad',
#  'ugggh idk wanna stop get text twitterr ils',
#  'wait novemb jobro concert examin',
#  'done alway end sell machin go back mac',
#  'came back watch termin salvat cathay much action feel sorri marcu though',
#  'sit thru bore bit titan wait good bit start coupl hour',
#  'http twitpic com jken fire urban rock challeng',
#  'believ thought morn shift today told alex could take airport flight shift',
#  'poor heather didnt make cheerlead squad im sorri babygirl mayb next year',
#  'well',
#  'e crazzyyyy summer cuz ci close rd',
#  'ju love doin night shift done hour',
#  'morn tweepl way earli',
#  'reupload thing',
#  'know updat realli amus prop auction much baseship bed go',
#  'love fact day school left',
#  'oh hope bad',
#  'awesom headin nite grad dinner c u boi hehe',
#  'beeri yeah littl rough morn tonight tomorrow night goe plan calor intak chart',
#  'aww congrat famili send picci email',
#  'uber bore atm blue shower watch hous numb rs vid csi csi ny bone doubl yay',
#  '',
#  'strongli agre jason wolverin hugh jackman sorri kid mous',
#  'okay bbi',
#  'okay okay sleep realz goodnight wave follow',
#  'omg mom call im late he gone',
#  'lost internet signal life go',
#  'sorri get chanc chat screengrab caught glimps across room drag home prematur',
#  'buckley good mate sadli couldnt get piss tonight drive bad time',
#  'bit tongu blood everywher',
#  'pull walmart aunt got went fell asleep hour later r lol',
#  'search home thing cook dinner even mother day guess im eat',
#  'cute fun watch',
#  'woke fell back sleep woke back sleep woke stay awak morn',
#  'great weekend even though site move plenti thing learn keep faith look futur',
#  'know realli hurt arm guess booz ask believ',
#  'go danc recit feel like piec cuz cost much money',
#  'tiiiiiiir go bed drink lead make boy later forget name drink kid goodnight',
#  'kind mood reason lol tri mushi around behav',
#  'that dote husband lol hope brace go eat normal',
#  'keep get delay respons internet mess',
#  'dont tell burnsi comparison rocki mountain mountain enlgland',
#  'know sad',
#  'good morn twit let make today x better one start runnin',
#  'could get away dare go buy tomorrow',
#  'thank man sort ever rememb',
#  'craig g hope enjoy money look real good right',
#  'favourit shirt true grumpi cute b huggabl c life parti http tinyurl com q eax',
#  'ok back pack sit car charg phone charger left home well',
#  'thank fr yr congratulatori gweetin',
#  'everi time friday sadli often',
#  'star trek good time',
#  'sun cool',
#  'meeeaaannn peopl make mistak ok lol',
#  'invis car help boost recycl honest http twurl nl fdgmyo',
#  'babi babi gonna right side whole world turn ipod random bsb song',
#  'ha total post updat lightn outsid pretti',
#  'tour philippin sometim lot fan would realli love',
#  'broken fb wed sadli longer excus get hauntingxealot goulburn',
#  'kickabl',
#  'richi also saw u american idol great perform see u windsor june commodor',
#  'nice clutch',
#  'happi mother day mommi',
#  'finish watch marley',
#  'enjoy mother day',
#  'everyon seem love felt kinda lazi repet realli disappoint',
#  'roll thursday',
#  'dadgum think nation ship need shut complet still freight carrier',
#  'cav got lucki night lol lebron took kill em anoth tripl doubl',
#  'wish mommi happi day',
#  'learn today never post anyth sold ebay use royal mail lose refund compo nowher near bad',
#  'oh god yeah forgot',
#  'long someon make lol',
#  'ahaha stuck head thanxx',
#  'arent follow cant send dm',
#  'poorli sleep',
#  'happi star war day may th read http tinyurl com axsujx',
#  'pick taco lunch got guitar',
#  'buri web chang go make lunch chanc later much',
#  'sold',
#  'hope everyon great weekend today import meet today',
#  'gd whoaa kinda hard one think interest enough tell',
#  'http twitpic com qpzx love guy best',
#  'listen music home alon lol want come hang lol',
#  'shut face mean pedro suppos mean one',
#  'month put week notic littl week ago last day friday',
#  'oh yea mspacer boy hook page look kewl least think took minut www myspac com missmickey',
#  'babe woo im get mine monday cant wait x',
#  'awww laavli come got stun wee tan l',
#  'ye pleas gone might actual get work done lol',
#  'realli get sick ugh nurs home lay bed might go run later watch movi austin sara sami left',
#  'saw stalkerishli elev brooki eat moracca go',
#  'youtub',
#  'call mum ask ice cream',
#  'lazi day play xbox drink tea',
#  'well disappoint hear',
#  'well use tweet push make go shop time im back hope',
#  'mom text told rodney chase firefli backyard awwwww miss http twitpic com pn',
#  'get readi bed happi mother day mother',
#  'blink fast better lol thank',
#  'leg kill know good pain',
#  'cont bastard version french fun believ',
#  'ala move like move actual move ugh wish could go',
#  'readi go home',
#  'need push diet last level good last week lost lb better gain',
#  'today jon doe play moho ia excit gonna funni carri equip backlin',
#  'back kill keep drop low hope got someon pick back tho lol',
#  'facebook',
#  'mad rain got cant go see jaiden',
#  'grandpar place',
#  'hi chile deg c winter come cant wait cali sun',
#  'dont feel good',
#  'born',
#  'congradt ur show even tho wasnt lol',
#  'damjust finish watch prison break final break omg dont think cri hard show final understand final',
#  'visit grandpar manhattan drop sister week wish excus tire today',
#  'glad friday two class lazi afternoon bad isnt nice warm today',
#  'good luck final long time panvel tweetup final come true',
#  'head hollywood studio today manta kraken awesom yesterday feel like ride',
#  'weekend go pack full work school life summer afraid',
#  'pleas read blog http amandallynn blogspot com best day',
#  'aid goodnight',
#  'welcom',
#  'ha thank bryan remind state budget issu actual steve staffer offic',
#  'thank none close',
#  'water tomato plant pepper plant lettuc feel home freddi fun pack day',
#  'haha rememb',
#  'hee exam give u plenti show haha hopeless',
#  'sorri',
#  'awww remind get readi ball',
#  'know rememb',
#  'bishop sez need get u look flight email ur work tonit',
#  'tmobil g hummer h wish batteri life iphon',
#  'nite nite twitt wish u happi sunday alreadi major gift kid bro n agressiva n gift way tyg',
#  'omg kim possibl disney channel right glu screen',
#  'first thought bar life meant parti nonstop catch last year lol shoulda known better',
#  'work heat horribl',
#  'someon came sleep nation passtim turn human',
#  'see shave head love cut glad shave hair pretti',
#  'starr yep hawkesburi classic start windsor home said dj',
#  'twitter like boss thank savvv',
#  'sleep pattern screw need tri stay midnight get decent sleep coz havent slept',
#  'sinc demis woolworth easi find reason price pick n mix anywher',
#  'may fourth happi star war day',
#  'unlock decad lucki never gottta make luck involv',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=3000)
X_fin=cv.fit_transform(cleaned_data).toarray()

# %%
sentiment_ordering = ['negative', 'neutral', 'positive']
y = y.apply(lambda x: sentiment_ordering.index(x))

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_fin,y,test_size=0.3)
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import classification_report
cf=classification_report(y_test,y_pred)
print(cf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.61      0.64      2317
#            1       0.61      0.67      0.64      3344
#            2       0.71      0.67      0.69      2584
#
#     accuracy                           0.65      8245
#    macro avg       0.66      0.65      0.66      8245
# weighted avg       0.66      0.65      0.65      8245
