# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=["Date"])

# %%
import matplotlib.pyplot as plt
df["High"][:'2016'].plot(figsize=(16, 4), legend=True)
df["High"]['2017':].plot(figsize=(16, 4), legend=True)
plt.legend(['Training set (Before 2017)', 'Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
trainning_set = df[:'2016'].iloc[:,1:2].values
test_set = df['2017':].iloc[:,1:2].values

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(trainning_set)

# %%
X_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
  X_train.append(training_set_scaled[i - 60:i, 0])
  y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units=80, return_sequences=True))
regressor.add(Dropout(0.1))

regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=30))
regressor.add(Dropout(0.3))

regressor.add(Dense(units=1))


regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 41s 321ms/step - loss: 0.0244
# Epoch 2/50
# 85/85 [==============================] - 24s 284ms/step - loss: 0.0092
# Epoch 3/50
# 85/85 [==============================] - 20s 236ms/step - loss: 0.0074
# Epoch 4/50
# 85/85 [==============================] - 17s 197ms/step - loss: 0.0072
# Epoch 5/50
# 85/85 [==============================] - 15s 171ms/step - loss: 0.0066
# Epoch 6/50
# 85/85 [==============================] - 15s 172ms/step - loss: 0.0066
# Epoch 7/50
# 85/85 [==============================] - 16s 186ms/step - loss: 0.0055
# Epoch 8/50
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0056
# Epoch 9/50
# 85/85 [==============================] - 16s 186ms/step - loss: 0.0051
# Epoch 10/50
# 85/85 [==============================] - 17s 198ms/step - loss: 0.0047
# Epoch 11/50
# 85/85 [==============================] - 17s 195ms/step - loss: 0.0051
# Epoch 12/50
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0043
# Epoch 13/50
# 85/85 [==============================] - 15s 182ms/step - loss: 0.0042
# Epoch 14/50
# 85/85 [==============================] - 14s 169ms/step - loss: 0.0040
# Epoch 15/50
# 85/85 [==============================] - 14s 159ms/step - loss: 0.0035
# Epoch 16/50
# 85/85 [==============================] - 23s 271ms/step - loss: 0.0034
# Epoch 17/50
# 85/85 [==============================] - 24s 278ms/step - loss: 0.0036
# Epoch 18/50
# 85/85 [==============================] - 17s 203ms/step - loss: 0.0034
# Epoch 19/50
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0033
# Epoch 20/50
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0031
# Epoch 21/50
# 85/85 [==============================] - 15s 172ms/step - loss: 0.0030
# Epoch 22/50
# 85/85 [==============================] - 15s 174ms/step - loss: 0.0028
# Epoch 23/50
# 85/85 [==============================] - 15s 175ms/step - loss: 0.0028
# Epoch 24/50
# 85/85 [==============================] - 17s 198ms/step - loss: 0.0025
# Epoch 25/50
# 85/85 [==============================] - 17s 197ms/step - loss: 0.0025
# Epoch 26/50
# 85/85 [==============================] - 16s 189ms/step - loss: 0.0025
# Epoch 27/50
# 85/85 [==============================] - 16s 188ms/step - loss: 0.0026
# Epoch 28/50
# 85/85 [==============================] - 15s 181ms/step - loss: 0.0024
# Epoch 29/50
# 85/85 [==============================] - 15s 182ms/step - loss: 0.0022
# Epoch 30/50
# 85/85 [==============================] - 15s 175ms/step - loss: 0.0023
# Epoch 31/50
# 85/85 [==============================] - 14s 169ms/step - loss: 0.0022
# Epoch 32/50
# 85/85 [==============================] - 15s 177ms/step - loss: 0.0020
# Epoch 33/50
# 85/85 [==============================] - 18s 215ms/step - loss: 0.0021
# Epoch 34/50
# 85/85 [==============================] - 20s 236ms/step - loss: 0.0021
# Epoch 35/50
# 85/85 [==============================] - 22s 252ms/step - loss: 0.0020
# Epoch 36/50
# 85/85 [==============================] - 28s 330ms/step - loss: 0.0019
# Epoch 37/50
# 85/85 [==============================] - 22s 262ms/step - loss: 0.0021
# Epoch 38/50
# 85/85 [==============================] - 21s 244ms/step - loss: 0.0019
# Epoch 39/50
# 85/85 [==============================] - 15s 181ms/step - loss: 0.0020
# Epoch 40/50
# 85/85 [==============================] - 16s 184ms/step - loss: 0.0020
# Epoch 41/50
# 85/85 [==============================] - 17s 197ms/step - loss: 0.0019
# Epoch 42/50
# 85/85 [==============================] - 16s 186ms/step - loss: 0.0019
# Epoch 43/50
# 85/85 [==============================] - 17s 197ms/step - loss: 0.0018
# Epoch 44/50
# 85/85 [==============================] - 17s 207ms/step - loss: 0.0019
# Epoch 45/50
# 85/85 [==============================] - 16s 185ms/step - loss: 0.0017
# Epoch 46/50
# 85/85 [==============================] - 16s 186ms/step - loss: 0.0018
# Epoch 47/50
# 85/85 [==============================] - 15s 173ms/step - loss: 0.0019
# Epoch 48/50
# 85/85 [==============================] - 17s 200ms/step - loss: 0.0016
# Epoch 49/50
# 85/85 [==============================] - 15s 172ms/step - loss: 0.0018
# Epoch 50/50
# 85/85 [==============================] - 15s 177ms/step - loss: 0.0020

# %%
dataset_total = pd.concat((df["High"][:'2016'],df["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# making the test data
X_test = []
for i in range(60,len(inputs)):
  X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 [==============================] - 2s 63ms/step

# %%
def plot_prediction(test,prediction):
    plt.plot(test,color='red',label="Real IBM Stock Price")
    plt.plot(prediction, color="blue",label="predicted IBM Stock price")
    plt.title("IBM Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("IBM Stock Price")
    plt.legend()
    plt.show()
# now we'll use this function to visualize our test and predicted data

plot_prediction(test_set,predicted_stock_price)

# %%
from sklearn.metrics import mean_squared_error
import math
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test,predicted))
    print("The root mean sqaured error is {}.".format(rmse))

return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean sqaured error is 2.7404665665512025.

# %%
import tensorflow as tf
from keras.layers import GRU
regressorGRU = Sequential()

regressorGRU.add(GRU(units=100, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.3))
# Second GRU layer
regressorGRU.add(GRU(units=80, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Third GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.1))
# Fourth GRU layer
regressorGRU.add(GRU(units=30, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# The output layer
regressorGRU.add(Dense(units=1))

# Compiling the RNN
regressorGRU.compile(optimizer='adam',loss='mean_squared_error')

# Fitting to the training set
regressorGRU.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 19s 497ms/step - loss: 0.0639
# Epoch 2/50
# 19/19 [==============================] - 8s 413ms/step - loss: 0.0122
# Epoch 3/50
# 19/19 [==============================] - 9s 489ms/step - loss: 0.0069
# Epoch 4/50
# 19/19 [==============================] - 9s 477ms/step - loss: 0.0060
# Epoch 5/50
# 19/19 [==============================] - 14s 751ms/step - loss: 0.0054
# Epoch 6/50
# 19/19 [==============================] - 16s 850ms/step - loss: 0.0051
# Epoch 7/50
# 19/19 [==============================] - 9s 464ms/step - loss: 0.0052
# Epoch 8/50
# 19/19 [==============================] - 11s 566ms/step - loss: 0.0051
# Epoch 9/50
# 19/19 [==============================] - 7s 373ms/step - loss: 0.0051
# Epoch 10/50
# 19/19 [==============================] - 10s 553ms/step - loss: 0.0046
# Epoch 11/50
# 19/19 [==============================] - 7s 378ms/step - loss: 0.0047
# Epoch 12/50
# 19/19 [==============================] - 11s 563ms/step - loss: 0.0042
# Epoch 13/50
# 19/19 [==============================] - 7s 371ms/step - loss: 0.0042
# Epoch 14/50
# 19/19 [==============================] - 10s 561ms/step - loss: 0.0040
# Epoch 15/50
# 19/19 [==============================] - 7s 380ms/step - loss: 0.0040
# Epoch 16/50
# 19/19 [==============================] - 11s 613ms/step - loss: 0.0040
# Epoch 17/50
# 19/19 [==============================] - 8s 418ms/step - loss: 0.0040
# Epoch 18/50
# 19/19 [==============================] - 10s 507ms/step - loss: 0.0039
# Epoch 19/50
# 19/19 [==============================] - 7s 357ms/step - loss: 0.0042
# Epoch 20/50
# 19/19 [==============================] - 11s 549ms/step - loss: 0.0043
# Epoch 21/50
# 19/19 [==============================] - 7s 371ms/step - loss: 0.0037
# Epoch 22/50
# 19/19 [==============================] - 11s 548ms/step - loss: 0.0037
# Epoch 23/50
# 19/19 [==============================] - 7s 388ms/step - loss: 0.0040
# Epoch 24/50
# 19/19 [==============================] - 10s 542ms/step - loss: 0.0040
# Epoch 25/50
# 19/19 [==============================] - 7s 372ms/step - loss: 0.0036
# Epoch 26/50
# 19/19 [==============================] - 10s 538ms/step - loss: 0.0034
# Epoch 27/50
# 19/19 [==============================] - 7s 373ms/step - loss: 0.0038
# Epoch 28/50
# 19/19 [==============================] - 11s 586ms/step - loss: 0.0034
# Epoch 29/50
# 19/19 [==============================] - 9s 466ms/step - loss: 0.0034
# Epoch 30/50
# 19/19 [==============================] - 9s 469ms/step - loss: 0.0033
# Epoch 31/50
# 19/19 [==============================] - 8s 423ms/step - loss: 0.0034
# Epoch 32/50
# 19/19 [==============================] - 9s 489ms/step - loss: 0.0034
# Epoch 33/50
# 19/19 [==============================] - 8s 425ms/step - loss: 0.0037
# Epoch 34/50
# 19/19 [==============================] - 10s 500ms/step - loss: 0.0033
# Epoch 35/50
# 19/19 [==============================] - 8s 430ms/step - loss: 0.0033
# Epoch 36/50
# 19/19 [==============================] - 9s 461ms/step - loss: 0.0030
# Epoch 37/50
# 19/19 [==============================] - 7s 383ms/step - loss: 0.0032
# Epoch 38/50
# 19/19 [==============================] - 10s 514ms/step - loss: 0.0031
# Epoch 39/50
# 19/19 [==============================] - 7s 364ms/step - loss: 0.0032
# Epoch 40/50
# 19/19 [==============================] - 11s 591ms/step - loss: 0.0030
# Epoch 41/50
# 19/19 [==============================] - 8s 435ms/step - loss: 0.0032
# Epoch 42/50
# 19/19 [==============================] - 10s 497ms/step - loss: 0.0029
# Epoch 43/50
# 19/19 [==============================] - 8s 422ms/step - loss: 0.0031
# Epoch 44/50
# 19/19 [==============================] - 9s 477ms/step - loss: 0.0029
# Epoch 45/50
# 19/19 [==============================] - 8s 411ms/step - loss: 0.0030
# Epoch 46/50
# 19/19 [==============================] - 9s 486ms/step - loss: 0.0027
# Epoch 47/50
# 19/19 [==============================] - 7s 372ms/step - loss: 0.0030
# Epoch 48/50
# 19/19 [==============================] - 10s 518ms/step - loss: 0.0027
# Epoch 49/50
# 19/19 [==============================] - 7s 353ms/step - loss: 0.0028
# Epoch 50/50
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0029

# %%
X_test = []
for i in range(60,len(inputs)):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price1 = regressorGRU.predict(X_test)
predicted_stock_price1 = sc.inverse_transform(predicted_stock_price1)
# Out:
# 8/8 [==============================] - 2s 34ms/step

# %%
return_rmse(test_set, predicted_stock_price1)
# Out:
# The root mean sqaured error is 3.5776749146245845.

# %%
plot_prediction(test_set,predicted_stock_price1)
